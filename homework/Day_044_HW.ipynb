# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
def draw_keypoints(img, points):
    x = points[::2]
    y = points[1::2]
    x = (x + 0.5)*96
    y = (y + 0.5)*96
    plt.imshow(img, cmap='gray')
    plt.scatter(x, y, s=10, c='r', alpha=1)
# 實現圖片以及關機點 label 做左右翻轉的函數
def data_augment(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = data_augment(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
draw_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
draw_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
imgs_train_aug = []
points_train_aug = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    img_aug, point_aug = data_augment(imgs_train[i], points_train[i])
    
    # append 原始資料
    imgs_train_aug.append(imgs_train[i])
    points_train_aug.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    imgs_train_aug.append(img_aug)
    points_train_aug.append(point_aug) 

# convert to numpy
imgs_train_aug = np.array(imgs_train_aug)   
points_train_aug = np.copy(points_train_aug)

print("圖像資料(aug):", imgs_train_aug.shape, "\n關鍵點資料(aug):", points_train_aug.shape)
# Out:
# 圖像資料(aug): (4280, 96, 96)
# 關鍵點資料(aug): (4280, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train_aug.reshape(-1, 96, 96, 1), 
                       points_train_aug, 
                       validation_split=0.2, batch_size=16, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=100, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/100
# 3424/3424 [==============================] - 11s 3ms/step - loss: 0.0021 - val_loss: 0.0020
#
# Epoch 00001: val_loss improved from inf to 0.00195, saving model to best_weights.h5
# Epoch 2/100
# 3424/3424 [==============================] - 2s 473us/step - loss: 9.0852e-04 - val_loss: 0.0015
#
# Epoch 00002: val_loss improved from 0.00195 to 0.00150, saving model to best_weights.h5
# Epoch 3/100
# 3424/3424 [==============================] - 2s 477us/step - loss: 5.9721e-04 - val_loss: 0.0011
#
# Epoch 00003: val_loss improved from 0.00150 to 0.00106, saving model to best_weights.h5
# Epoch 4/100
# 3424/3424 [==============================] - 2s 479us/step - loss: 4.7880e-04 - val_loss: 9.1909e-04
#
# Epoch 00004: val_loss improved from 0.00106 to 0.00092, saving model to best_weights.h5
# Epoch 5/100
# 3424/3424 [==============================] - 2s 478us/step - loss: 4.0440e-04 - val_loss: 8.6423e-04
#
# Epoch 00005: val_loss improved from 0.00092 to 0.00086, saving model to best_weights.h5
# Epoch 6/100
# 3424/3424 [==============================] - 2s 474us/step - loss: 3.5729e-04 - val_loss: 7.8795e-04
#
# Epoch 00006: val_loss improved from 0.00086 to 0.00079, saving model to best_weights.h5
# Epoch 7/100
# 3424/3424 [==============================] - 2s 478us/step - loss: 3.3320e-04 - val_loss: 7.6603e-04
#
# Epoch 00007: val_loss improved from 0.00079 to 0.00077, saving model to best_weights.h5
# Epoch 8/100
# 3424/3424 [==============================] - 2s 476us/step - loss: 2.9664e-04 - val_loss: 7.6570e-04
#
# Epoch 00008: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 9/100
# 3424/3424 [==============================] - 2s 474us/step - loss: 2.7879e-04 - val_loss: 7.6114e-04
#
# Epoch 00009: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 10/100
# 3424/3424 [==============================] - 2s 475us/step - loss: 2.6071e-04 - val_loss: 6.5598e-04
#
# Epoch 00010: val_loss improved from 0.00076 to 0.00066, saving model to best_weights.h5
# Epoch 11/100
# 3424/3424 [==============================] - 2s 474us/step - loss: 2.4751e-04 - val_loss: 7.0691e-04
#
# Epoch 00011: val_loss did not improve from 0.00066
# Epoch 12/100
# 3424/3424 [==============================] - 2s 480us/step - loss: 2.3682e-04 - val_loss: 6.6151e-04
#
# Epoch 00012: val_loss did not improve from 0.00066
# Epoch 13/100
# 3424/3424 [==============================] - 2s 471us/step - loss: 2.2828e-04 - val_loss: 6.5056e-04
#
# Epoch 00013: val_loss improved from 0.00066 to 0.00065, saving model to best_weights.h5
# Epoch 14/100
# 3424/3424 [==============================] - 2s 479us/step - loss: 2.1854e-04 - val_loss: 5.9700e-04
#
# Epoch 00014: val_loss improved from 0.00065 to 0.00060, saving model to best_weights.h5
# Epoch 15/100
# 3424/3424 [==============================] - 2s 488us/step - loss: 2.0739e-04 - val_loss: 6.3671e-04
#
# Epoch 00015: val_loss did not improve from 0.00060
# Epoch 16/100
# 3424/3424 [==============================] - 2s 488us/step - loss: 2.0112e-04 - val_loss: 6.1060e-04
#
# Epoch 00016: val_loss did not improve from 0.00060
# Epoch 17/100
# 3424/3424 [==============================] - 2s 477us/step - loss: 1.9668e-04 - val_loss: 6.2375e-04
#
# Epoch 00017: val_loss did not improve from 0.00060
# Epoch 18/100
# 3424/3424 [==============================] - 2s 481us/step - loss: 1.8821e-04 - val_loss: 5.9686e-04
#
# Epoch 00018: val_loss improved from 0.00060 to 0.00060, saving model to best_weights.h5
# Epoch 19/100
# 3424/3424 [==============================] - 2s 477us/step - loss: 1.8652e-04 - val_loss: 6.6808e-04
#
# Epoch 00019: val_loss did not improve from 0.00060
# Epoch 20/100
# 3424/3424 [==============================] - 2s 475us/step - loss: 1.8001e-04 - val_loss: 6.0680e-04
#
# Epoch 00020: val_loss did not improve from 0.00060
# Epoch 21/100
# 3424/3424 [==============================] - 2s 474us/step - loss: 1.7396e-04 - val_loss: 5.8603e-04
#
# Epoch 00021: val_loss improved from 0.00060 to 0.00059, saving model to best_weights.h5
# Epoch 22/100
# 3424/3424 [==============================] - 2s 479us/step - loss: 1.7202e-04 - val_loss: 6.2768e-04
#
# Epoch 00022: val_loss did not improve from 0.00059
# Epoch 23/100
# 3424/3424 [==============================] - 2s 484us/step - loss: 1.7434e-04 - val_loss: 6.0971e-04
#
# Epoch 00023: val_loss did not improve from 0.00059
# Epoch 24/100
# 3424/3424 [==============================] - 2s 480us/step - loss: 1.6355e-04 - val_loss: 5.9103e-04
#
# Epoch 00024: val_loss did not improve from 0.00059
# Epoch 25/100
# 3424/3424 [==============================] - 2s 481us/step - loss: 1.6338e-04 - val_loss: 6.1655e-04
#
# Epoch 00025: val_loss did not improve from 0.00059
# Epoch 26/100
# 3424/3424 [==============================] - 2s 478us/step - loss: 1.5753e-04 - val_loss: 5.9487e-04
#
# Epoch 00026: val_loss did not improve from 0.00059
# Epoch 27/100
# 3424/3424 [==============================] - 2s 479us/step - loss: 1.5162e-04 - val_loss: 6.0265e-04
#
# Epoch 00027: val_loss did not improve from 0.00059
# Epoch 28/100
# 3424/3424 [==============================] - 2s 477us/step - loss: 1.5532e-04 - val_loss: 6.0273e-04
#
# Epoch 00028: val_loss did not improve from 0.00059
# Epoch 29/100
# 3424/3424 [==============================] - 2s 480us/step - loss: 1.5172e-04 - val_loss: 5.9190e-04
#
# Epoch 00029: val_loss did not improve from 0.00059
# Epoch 30/100
# 3424/3424 [==============================] - 2s 480us/step - loss: 1.5283e-04 - val_loss: 5.7415e-04
#
# Epoch 00030: val_loss improved from 0.00059 to 0.00057, saving model to best_weights.h5
# Epoch 31/100
# 3424/3424 [==============================] - 2s 475us/step - loss: 1.4713e-04 - val_loss: 5.9793e-04
#
# Epoch 00031: val_loss did not improve from 0.00057
# Epoch 32/100
# 3424/3424 [==============================] - 2s 480us/step - loss: 1.4716e-04 - val_loss: 6.0696e-04
#
# Epoch 00032: val_loss did not improve from 0.00057
# Epoch 33/100
# 3424/3424 [==============================] - 2s 474us/step - loss: 1.4904e-04 - val_loss: 6.0016e-04
#
# Epoch 00033: val_loss did not improve from 0.00057
# Epoch 34/100
# 3424/3424 [==============================] - 2s 478us/step - loss: 1.4018e-04 - val_loss: 6.0489e-04
#
# Epoch 00034: val_loss did not improve from 0.00057
# Epoch 35/100
# 3424/3424 [==============================] - 2s 477us/step - loss: 1.4620e-04 - val_loss: 5.8744e-04
#
# Epoch 00035: val_loss did not improve from 0.00057
# Epoch 36/100
# 3424/3424 [==============================] - 2s 479us/step - loss: 1.4381e-04 - val_loss: 5.9298e-04
#
# Epoch 00036: val_loss did not improve from 0.00057
# Epoch 37/100
# 3424/3424 [==============================] - 2s 475us/step - loss: 1.4011e-04 - val_loss: 6.3254e-04
#
# Epoch 00037: val_loss did not improve from 0.00057
# Epoch 38/100
# 3424/3424 [==============================] - 2s 475us/step - loss: 1.4232e-04 - val_loss: 6.0338e-04
#
# Epoch 00038: val_loss did not improve from 0.00057
# Epoch 39/100
# 3424/3424 [==============================] - 2s 473us/step - loss: 1.4506e-04 - val_loss: 5.8498e-04
#
# Epoch 00039: val_loss did not improve from 0.00057
# Epoch 40/100
# 3424/3424 [==============================] - 2s 479us/step - loss: 1.4359e-04 - val_loss: 6.0357e-04
#
# Epoch 00040: val_loss did not improve from 0.00057
# Epoch 41/100
# 3424/3424 [==============================] - 2s 474us/step - loss: 1.3890e-04 - val_loss: 6.2335e-04
#
# Epoch 00041: val_loss did not improve from 0.00057
# Epoch 42/100
# 3424/3424 [==============================] - 2s 475us/step - loss: 1.3377e-04 - val_loss: 5.8737e-04
#
# Epoch 00042: val_loss did not improve from 0.00057
# Epoch 43/100
# 3424/3424 [==============================] - 2s 475us/step - loss: 1.3237e-04 - val_loss: 5.8174e-04
#
# Epoch 00043: val_loss did not improve from 0.00057
# Epoch 44/100
# 3424/3424 [==============================] - 2s 477us/step - loss: 1.3060e-04 - val_loss: 6.0550e-04
#
# Epoch 00044: val_loss did not improve from 0.00057
# Epoch 45/100
# 3424/3424 [==============================] - 2s 479us/step - loss: 1.3161e-04 - val_loss: 6.2907e-04
#
# Epoch 00045: val_loss did not improve from 0.00057
# Epoch 46/100
# 3424/3424 [==============================] - 2s 475us/step - loss: 1.3311e-04 - val_loss: 6.3148e-04
#
# Epoch 00046: val_loss did not improve from 0.00057
# Epoch 47/100
# 3424/3424 [==============================] - 2s 476us/step - loss: 1.4230e-04 - val_loss: 6.0921e-04
#
# Epoch 00047: val_loss did not improve from 0.00057
# Epoch 48/100
# 3424/3424 [==============================] - 2s 475us/step - loss: 1.4044e-04 - val_loss: 6.1348e-04
#
# Epoch 00048: val_loss did not improve from 0.00057
# Epoch 49/100
# 3424/3424 [==============================] - 2s 479us/step - loss: 1.3430e-04 - val_loss: 6.1914e-04
#
# Epoch 00049: val_loss did not improve from 0.00057
# Epoch 50/100
# 3424/3424 [==============================] - 2s 476us/step - loss: 1.2939e-04 - val_loss: 6.2666e-04
#
# Epoch 00050: val_loss did not improve from 0.00057
# Epoch 51/100
# 3424/3424 [==============================] - 2s 474us/step - loss: 1.2956e-04 - val_loss: 6.4683e-04
#
# Epoch 00051: val_loss did not improve from 0.00057
# Epoch 52/100
# 3424/3424 [==============================] - 2s 478us/step - loss: 1.3630e-04 - val_loss: 5.9750e-04
#
# Epoch 00052: val_loss did not improve from 0.00057
# Epoch 53/100
# 3424/3424 [==============================] - 2s 483us/step - loss: 1.3326e-04 - val_loss: 6.1462e-04
#
# Epoch 00053: val_loss did not improve from 0.00057
# Epoch 54/100
# 3424/3424 [==============================] - 2s 483us/step - loss: 1.2896e-04 - val_loss: 6.3937e-04
#
# Epoch 00054: val_loss did not improve from 0.00057
# Epoch 55/100
# 3424/3424 [==============================] - 2s 479us/step - loss: 1.2663e-04 - val_loss: 6.0237e-04
#
# Epoch 00055: val_loss did not improve from 0.00057
# Epoch 56/100
# 3424/3424 [==============================] - 2s 475us/step - loss: 1.2488e-04 - val_loss: 6.1055e-04
#
# Epoch 00056: val_loss did not improve from 0.00057
# Epoch 57/100
# 3424/3424 [==============================] - 2s 477us/step - loss: 1.2228e-04 - val_loss: 6.1329e-04
#
# Epoch 00057: val_loss did not improve from 0.00057
# Epoch 58/100
# 3424/3424 [==============================] - 2s 476us/step - loss: 1.2835e-04 - val_loss: 6.1964e-04
#
# Epoch 00058: val_loss did not improve from 0.00057
# Epoch 59/100
# 3424/3424 [==============================] - 2s 477us/step - loss: 1.2564e-04 - val_loss: 6.1580e-04
#
# Epoch 00059: val_loss did not improve from 0.00057
# Epoch 60/100
# 3424/3424 [==============================] - 2s 476us/step - loss: 1.2362e-04 - val_loss: 6.2931e-04
#
# Epoch 00060: val_loss did not improve from 0.00057
# Epoch 61/100
# 3424/3424 [==============================] - 2s 475us/step - loss: 1.2648e-04 - val_loss: 6.4294e-04
#
# Epoch 00061: val_loss did not improve from 0.00057
# Epoch 62/100
# 3424/3424 [==============================] - 2s 474us/step - loss: 1.2508e-04 - val_loss: 6.1444e-04
#
# Epoch 00062: val_loss did not improve from 0.00057
# Epoch 63/100
# 3424/3424 [==============================] - 2s 479us/step - loss: 1.2253e-04 - val_loss: 6.5744e-04
#
# Epoch 00063: val_loss did not improve from 0.00057
# Epoch 64/100
# 3424/3424 [==============================] - 2s 474us/step - loss: 1.2299e-04 - val_loss: 6.0598e-04
#
# Epoch 00064: val_loss did not improve from 0.00057
# Epoch 65/100
# 3424/3424 [==============================] - 2s 474us/step - loss: 1.2435e-04 - val_loss: 6.2306e-04
#
# Epoch 00065: val_loss did not improve from 0.00057
# Epoch 66/100
# 3424/3424 [==============================] - 2s 475us/step - loss: 1.2355e-04 - val_loss: 6.1132e-04
#
# Epoch 00066: val_loss did not improve from 0.00057
# Epoch 67/100
# 3424/3424 [==============================] - 2s 476us/step - loss: 1.2240e-04 - val_loss: 6.1384e-04
#
# Epoch 00067: val_loss did not improve from 0.00057
# Epoch 68/100
# 3424/3424 [==============================] - 2s 475us/step - loss: 1.1693e-04 - val_loss: 6.3883e-04
#
# Epoch 00068: val_loss did not improve from 0.00057
# Epoch 69/100
# 3424/3424 [==============================] - 2s 474us/step - loss: 1.2220e-04 - val_loss: 6.2107e-04
#
# Epoch 00069: val_loss did not improve from 0.00057
# Epoch 70/100
# 3424/3424 [==============================] - 2s 476us/step - loss: 1.1753e-04 - val_loss: 5.9060e-04
#
# Epoch 00070: val_loss did not improve from 0.00057
# Epoch 71/100
# 3424/3424 [==============================] - 2s 475us/step - loss: 1.1848e-04 - val_loss: 6.3073e-04
#
# Epoch 00071: val_loss did not improve from 0.00057
# Epoch 72/100
# 3424/3424 [==============================] - 2s 476us/step - loss: 1.2259e-04 - val_loss: 5.9363e-04
#
# Epoch 00072: val_loss did not improve from 0.00057
# Epoch 73/100
# 3424/3424 [==============================] - 2s 488us/step - loss: 1.1989e-04 - val_loss: 6.6266e-04
#
# Epoch 00073: val_loss did not improve from 0.00057
# Epoch 74/100
# 3424/3424 [==============================] - 2s 481us/step - loss: 1.2065e-04 - val_loss: 6.1734e-04
#
# Epoch 00074: val_loss did not improve from 0.00057
# Epoch 75/100
# 3424/3424 [==============================] - 2s 477us/step - loss: 1.1881e-04 - val_loss: 6.3954e-04
#
# Epoch 00075: val_loss did not improve from 0.00057
# Epoch 76/100
# 3424/3424 [==============================] - 2s 475us/step - loss: 1.3087e-04 - val_loss: 6.3215e-04
#
# Epoch 00076: val_loss did not improve from 0.00057
# Epoch 77/100
# 3424/3424 [==============================] - 2s 475us/step - loss: 1.1973e-04 - val_loss: 6.2672e-04
#
# Epoch 00077: val_loss did not improve from 0.00057
# Epoch 78/100
# 3424/3424 [==============================] - 2s 484us/step - loss: 1.1837e-04 - val_loss: 6.2660e-04
#
# Epoch 00078: val_loss did not improve from 0.00057
# Epoch 79/100
# 3424/3424 [==============================] - 2s 479us/step - loss: 1.1650e-04 - val_loss: 6.3585e-04
#
# Epoch 00079: val_loss did not improve from 0.00057
# Epoch 80/100
# 3424/3424 [==============================] - 2s 481us/step - loss: 1.1403e-04 - val_loss: 6.2028e-04
#
# Epoch 00080: val_loss did not improve from 0.00057
# Epoch 81/100
# 3424/3424 [==============================] - 2s 481us/step - loss: 1.1461e-04 - val_loss: 6.1302e-04
#
# Epoch 00081: val_loss did not improve from 0.00057
# Epoch 82/100
# 3424/3424 [==============================] - 2s 477us/step - loss: 1.1290e-04 - val_loss: 5.8894e-04
#
# Epoch 00082: val_loss did not improve from 0.00057
# Epoch 83/100
# 3424/3424 [==============================] - 2s 478us/step - loss: 1.1440e-04 - val_loss: 6.5187e-04
#
# Epoch 00083: val_loss did not improve from 0.00057
# Epoch 84/100
# 3424/3424 [==============================] - 2s 480us/step - loss: 1.1359e-04 - val_loss: 6.3910e-04
#
# Epoch 00084: val_loss did not improve from 0.00057
# Epoch 85/100
# 3424/3424 [==============================] - 2s 480us/step - loss: 1.2096e-04 - val_loss: 6.3760e-04
#
# Epoch 00085: val_loss did not improve from 0.00057
# Epoch 86/100
# 3424/3424 [==============================] - 2s 475us/step - loss: 1.1809e-04 - val_loss: 6.5385e-04
#
# Epoch 00086: val_loss did not improve from 0.00057
# Epoch 87/100
# 3424/3424 [==============================] - 2s 480us/step - loss: 1.1454e-04 - val_loss: 6.3803e-04
#
# Epoch 00087: val_loss did not improve from 0.00057
# Epoch 88/100
# 3424/3424 [==============================] - 2s 473us/step - loss: 1.1287e-04 - val_loss: 6.1205e-04
#
# Epoch 00088: val_loss did not improve from 0.00057
# Epoch 89/100
# 3424/3424 [==============================] - 2s 486us/step - loss: 1.1659e-04 - val_loss: 6.8506e-04
#
# Epoch 00089: val_loss did not improve from 0.00057
# Epoch 90/100
# 3424/3424 [==============================] - 2s 483us/step - loss: 1.1730e-04 - val_loss: 6.1386e-04
#
# Epoch 00090: val_loss did not improve from 0.00057
# Epoch 91/100
# 3424/3424 [==============================] - 2s 476us/step - loss: 1.1369e-04 - val_loss: 6.0286e-04
#
# Epoch 00091: val_loss did not improve from 0.00057
# Epoch 92/100
# 3424/3424 [==============================] - 2s 477us/step - loss: 1.1166e-04 - val_loss: 6.2029e-04
#
# Epoch 00092: val_loss did not improve from 0.00057
# Epoch 93/100
# 3424/3424 [==============================] - 2s 477us/step - loss: 1.1137e-04 - val_loss: 6.2609e-04
#
# Epoch 00093: val_loss did not improve from 0.00057
# Epoch 94/100
# 3424/3424 [==============================] - 2s 478us/step - loss: 1.1165e-04 - val_loss: 6.7277e-04
#
# Epoch 00094: val_loss did not improve from 0.00057
# Epoch 95/100
# 3424/3424 [==============================] - 2s 482us/step - loss: 1.1026e-04 - val_loss: 6.3967e-04
#
# Epoch 00095: val_loss did not improve from 0.00057
# Epoch 96/100
# 3424/3424 [==============================] - 2s 477us/step - loss: 1.1485e-04 - val_loss: 6.3761e-04
#
# Epoch 00096: val_loss did not improve from 0.00057
# Epoch 97/100
# 3424/3424 [==============================] - 2s 476us/step - loss: 1.0965e-04 - val_loss: 6.5180e-04
#
# Epoch 00097: val_loss did not improve from 0.00057
# Epoch 98/100
# 3424/3424 [==============================] - 2s 474us/step - loss: 1.1177e-04 - val_loss: 6.4078e-04
#
# Epoch 00098: val_loss did not improve from 0.00057
# Epoch 99/100
# 3424/3424 [==============================] - 2s 474us/step - loss: 1.1430e-04 - val_loss: 6.3932e-04
#
# Epoch 00099: val_loss did not improve from 0.00057
# Epoch 100/100
# 3424/3424 [==============================] - 2s 490us/step - loss: 1.1332e-04 - val_loss: 6.4730e-04
#
# Epoch 00100: val_loss did not improve from 0.00057

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')
